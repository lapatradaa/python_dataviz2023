# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/python_dataviz2023/blob/main/%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%80%E0%B8%88%E0%B8%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #งานโปรเจค
#
#
# สมาชิกกลุ่ม
# *   นายธนบดี ภูชมศรี 643020502-4
# * นางสาวนริศรา โยธาจันทร์ 643020504-0
# * นางสาวนรีกานต์ ปัญญารักษ์ 643020505-8
# * นายรัชชานนท์ ทิพย์พิมานพร 643020515-5
# * นางสาวลภัสรดา แดงสูงเนิน 643020518-9
# * นายวุฒิชัย คำนา 643020521-0

# %% [markdown]
# #หัวข้อที่สนใจ
# 1. ต้องการทราบว่า พรรคการเมืองใดที่ได้คะแนนสูงสุดของสส.แบบแบ่งเขตในแต่ละจังหวัด
# 2.  ต้องการทราบว่า พรรคการเมืองใดที่ได้คะแนนสูงสุดของสส.บัญชีรายชื่อในแต่ละจังหวัด
# 3.  ต้องการทราบว่า ทั่วทั้งประเทศพรรคที่ได้คะแนนเสียงมากที่สุด 5 อันดับแรก มีพรรคอะไรบ้าง
# 4.  ต้องการทราบว่าใครคือส.ส.เเบบเเบ่งเขตที่มีคะเเนนเสียงมากที่สุดในพรรคการเมืองเเต่ละพรรค
# 5.  ต้องการทราบ สัดส่วนร้อยละผู้ที่เข้ามาใช้สิทธิ์ในแต่ละภูมิภาค เป็นเท่าใด

# %% [markdown]
# #Dashboard
# https://lookerstudio.google.com/reporting/da354ea8-c352-4840-88a4-a1492e5e20d6

# %% [markdown]
# #เตรียมข้อมูล

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='result_constituencies_PartyList')
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='result_constituencies_Candidate')
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='result_constituencies_status')
info_province = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='info_province')
info_party_overview = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='info_party_overview')
info_constituency = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='info_constituency')
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='Candidate_Constituency')
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='Candidate_PartyList')
Candidate_PM = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='Candidate_PM')
region = pd.read_excel('/content/drive/MyDrive/Dataviz_23data/ectreport2023_มีภาค.xlsx',sheet_name='region')

# %% [markdown]
# เครียส์MISSing

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
info_party_overview['party_no']=info_party_overview['party_no'].fillna(99)

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, party_no, name, abbr, color, logo_url]
# Index: []

# %%
info_constituency[info_constituency['zone'].isnull()]
# Out:
#      cons_id  cons_no prov_id  registered_vote  total_vote_stations zone
# 804    RNG_1        1     RNG           140024                  209  NaN
# 817    SBR_1        1     SBR           168055                  213  NaN
# 839    SKM_1        1     SKM           156558                  257  NaN
# 1037   TRT_1        1     TRT           175112                  314  NaN

# %%
import numpy as np
# แทนค่าว่าง
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'RNG', 'อำเภอเมืองระนอง', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SBR', 'อำเภอเมืองสิงห์บุรี', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SKM', 'อำเภอเมืองสมุทรสงคราม', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'TRT', 'อำเภอเมืองตราด', info_constituency['zone'])

# %%
info_constituency[info_constituency['zone'].isnull()]
# Out:
# Empty DataFrame
# Columns: [cons_id, cons_no, prov_id, registered_vote, total_vote_stations, zone]
# Index: []

# %% [markdown]
# 1.แต่ละจังหวัดเลือกพรรคอะไรมากที่สุด

# %%
table_merge = result_constituencies_Candidate.merge(Candidate_Constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(table_merge.shape)
table_merge.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
table_merge1 = table_merge.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(table_merge1.shape)
table_merge1.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  706      14.0
# 1  https://cdn.ectreport.com/images/mp_candidates...  709       7.0
# 2  https://cdn.ectreport.com/images/mp_candidates...  712       2.0
# 3  https://cdn.ectreport.com/images/mp_candidates...  742      61.0
# 4  https://cdn.ectreport.com/images/mp_candidates...  761       5.0
#
#               name    abbr    color  \
# 0    ชาติพัฒนากล้า    ชพก.  #233e8a
# 1        ภูมิใจไทย     ภท.  #0c149c
# 2  ประชาธิปไตยใหม่    ปธม.  #eb4138
# 3          คลองไทย   คล.ท.  #0eafeb
# 4    พลังสังคมใหม่  พ.ส.ม.  #eabcc3
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# 1  https://cdn.ectreport.com/images/logos/ภูมิใจไ...
# 2  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 3  https://cdn.ectreport.com/images/logos/คลองไทย...
# 4  https://cdn.ectreport.com/images/logos/พลังสัง...

# %%
table_merge2 = table_merge1.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (4781, 22)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...             name  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...    ชาติพัฒนากล้า
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...        ภูมิใจไทย
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...  ประชาธิปไตยใหม่
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...          คลองไทย
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...    พลังสังคมใหม่
#
#      abbr    color                                           logo_url prov_id  \
# 0    ชพก.  #233e8a  https://cdn.ectreport.com/images/logos/ชาติพัฒ...     ACR
# 1     ภท.  #0c149c  https://cdn.ectreport.com/images/logos/ภูมิใจไ...     ACR
# 2    ปธม.  #eb4138  https://cdn.ectreport.com/images/logos/ประชาธิ...     ACR
# 3   คล.ท.  #0eafeb  https://cdn.ectreport.com/images/logos/คลองไทย...     ACR
# 4  พ.ส.ม.  #eabcc3  https://cdn.ectreport.com/images/logos/พลังสัง...     ACR
#
#   turn_out percent_turn_out  counted_vote_stations  percent_count  \
# 0   105574         72.60136                    310          100.0
# 1   105574         72.60136                    310          100.0
# 2   105574         72.60136                    310          100.0
# 3   105574         72.60136                    310          100.0
# 4   105574         72.60136                    310          100.0
#
#    pause_report
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 22 columns]

# %%
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 29)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...
#
#    counted_vote_stations  percent_count pause_report province_id    province  \
# 0                    310          100.0        False          37  อำนาจเจริญ
# 1                    310          100.0        False          37  อำนาจเจริญ
# 2                    310          100.0        False          37  อำนาจเจริญ
# 3                    310          100.0        False          37  อำนาจเจริญ
# 4                    310          100.0        False          37  อำนาจเจริญ
#
#              eng abbre_thai  total_registered_vote  total_vote_stations  \
# 0  AMNAT CHAROEN         อจ                 301354                  641
# 1  AMNAT CHAROEN         อจ                 301354                  641
# 2  AMNAT CHAROEN         อจ                 301354                  641
# 3  AMNAT CHAROEN         อจ                 301354                  641
# 4  AMNAT CHAROEN         อจ                 301354                  641
#
#    region_id
# 0        R02
# 1        R02
# 2        R02
# 3        R02
# 4        R02
#
# [5 rows x 29 columns]

# %%
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 29)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...
#
#    counted_vote_stations  percent_count pause_report province_id    province  \
# 0                    310          100.0        False          37  อำนาจเจริญ
# 1                    310          100.0        False          37  อำนาจเจริญ
# 2                    310          100.0        False          37  อำนาจเจริญ
# 3                    310          100.0        False          37  อำนาจเจริญ
# 4                    310          100.0        False          37  อำนาจเจริญ
#
#              eng abbre_thai  total_registered_vote  total_vote_stations  \
# 0  AMNAT CHAROEN         อจ                 301354                  641
# 1  AMNAT CHAROEN         อจ                 301354                  641
# 2  AMNAT CHAROEN         อจ                 301354                  641
# 3  AMNAT CHAROEN         อจ                 301354                  641
# 4  AMNAT CHAROEN         อจ                 301354                  641
#
#    region_id
# 0        R02
# 1        R02
# 2        R02
# 3        R02
# 4        R02
#
# [5 rows x 29 columns]

# %%
table_merge4 = table_merge3.merge(region, how ='left', left_on='region_id',right_on='region_id')
print(table_merge3.shape)
table_merge4.head()
# Out:
# (4781, 29)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  percent_count  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 1  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 2  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 3  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
# 4  https://cdn.ectreport.com/images/mp_candidates...  ...          100.0
#
#    pause_report province_id    province            eng abbre_thai  \
# 0         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 1         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 2         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 3         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 4         False          37  อำนาจเจริญ  AMNAT CHAROEN         อจ
#
#   total_registered_vote  total_vote_stations  region_id            region_name
# 0                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 1                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 2                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 3                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
# 4                301354                  641        R02  ภาคตะวันออกเฉียงเหนือ
#
# [5 rows x 30 columns]

# %% [markdown]
# #เรียงคะเเนนเสียงจากรายชื่อว่าที่ ส.ส. จากมากไปน้อย โดยต้องการรู้ "ชื่อจังหวัด พรรคที่สังกัด ชื่อว่าที่ส.ส.เเละคะเเนนเสียง"

# %%
find_ma = result_constituencies_Candidate.sort_values(by='mp_app_vote',ascending=False)
find_ma1 = find_ma.merge(info_constituency,how='left', on='cons_id')
find_ma2 = find_ma1.merge(info_province,how='left', on='prov_id')
find_ma3 = find_ma2.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_ma4 = find_ma3.merge(Candidate_Constituency,how='left', on='mp_app_id')

# %%
find_mashow =find_ma4[['province','name','mp_app_name']]
find_mashow['mp_app_vote_'] = find_ma4[['mp_app_vote']]
find_mashow
# Out:
# <ipython-input-81-9fd55a1fecaa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   find_mashow['mp_app_vote_'] = find_ma4[['mp_app_vote']]
#           province            name               mp_app_name  mp_app_vote_
# 0             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 1             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 2             ตรัง    พลังประชารัฐ            นายทวี สุระบาล         63185
# 3      อุบลราชธานี  เพื่อไทรวมพลัง      นายสมศักดิ์ บุญประชม         63127
# 4      อุบลราชธานี  เพื่อไทรวมพลัง      นายสมศักดิ์ บุญประชม         63127
# ...            ...             ...                       ...           ...
# 13503        สงขลา         คลองไทย        นางลักขณา บุญรักษ์             0
# 13504      นนทบุรี       พลังสังคม  นายรัฐศิลป์ นลินธนาพัฒน์             0
# 13505      นนทบุรี       พลังสังคม  นายรัฐศิลป์ นลินธนาพัฒน์             0
# 13506        สงขลา         คลองไทย           นายมีชัย เทศนอก             0
# 13507        สงขลา         คลองไทย           นายมีชัย เทศนอก             0
#
# [13508 rows x 4 columns]

# %%
use_V0=find_mashow[['name','mp_app_name','mp_app_vote_']]
prov_vote=find_mashow.groupby('province')[['mp_app_vote_']].max().reset_index()
use_V1 = prov_vote.merge(use_V0,how='left', on='mp_app_vote_')
bool_use = use_V1.duplicated(subset='province')
use_V1 = use_V1[~bool_use]
# displaying data
use_V1.info()
#use_V1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 232
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   province      77 non-null     object
#  1   mp_app_vote_  77 non-null     int64
#  2   name          77 non-null     object
#  3   mp_app_name   77 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# #โค้ดส่วนนี้ เรืยงคะเเนนเสียง(เปอร์เซ็น) บนรายชื่อว่าที่สส.ในเเต่ละพรรคการเมืองเพื่อหาว่า ว่าที่สส.คนไหนมีเปอร์เซ็นคะเเนนเสียงมากที่สุด

# %% [markdown]
# พรรคก้าวไกล

# %%
find_proforcon1 = result_constituencies_Candidate.merge(info_party_overview,how='left', left_on='party_id',right_on='id')
find_proforcon = find_proforcon1.merge(Candidate_Constituency,how='left', on='mp_app_id')

# %%
fastfor_w = find_proforcon[find_proforcon['name']=='ก้าวไกล']
TOP_fast = fastfor_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_fast_soft = TOP_fast.sort_values(by='mp_app_vote_percent', ascending=False)
#TOP_fast_soft

# %%
def math_pa(x):
  y=(100*x)/1220778
  return y

# %%
final_TOP1 = TOP_fast_soft.replace(to_replace=279.88491,
           value=math_pa(279.88491)).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
#final_TOP1

# %% [markdown]
# พรรคเพื่อไทย

# %%
forthai_w = find_proforcon[find_proforcon['name']=='เพื่อไทย']
TOP_thai = forthai_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_thai_soft = TOP_thai.sort_values(by='mp_app_vote_percent', ascending=False)
#TOP_thai_soft

# %%
final_TOP2 = TOP_thai_soft.replace(to_replace=146.37719,
           value=math_pa(146.37719)).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
#final_TOP2

# %% [markdown]
# พรรคภูมิใจไทย

# %%
poothai_w = find_proforcon[find_proforcon['name']=='ภูมิใจไทย']
TOP_poo = poothai_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_poo_soft = TOP_poo.sort_values(by='mp_app_vote_percent', ascending=False)
#TOP_poo_soft

# %%
final_TOP3 = TOP_poo_soft.replace(to_replace=608.42270,
           value=math_pa(608.42270)).sort_values(by='mp_app_vote_percent', ascending=False)
#final_TOP3

# %% [markdown]
# พรรค พลังประชารัฐ

# %%
power_w = find_proforcon[find_proforcon['name']=='พลังประชารัฐ']
TOP_power_w = power_w[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_power_w = TOP_power_w.sort_values(by='mp_app_vote_percent', ascending=False)
#TOP_power_w

# %%
final_TOP4 = TOP_power_w.replace(to_replace=714.90976,
           value=math_pa(714.90976)).sort_values(by='mp_app_vote_percent', ascending=False)
#final_TOP4

# %% [markdown]
# พรรค รวมไทยสร้าง

# %%
how_are = find_proforcon[find_proforcon['name']=='รวมไทยสร้างชาติ']
TOP_how_are = how_are[['mp_app_name','mp_app_vote','mp_app_vote_percent']]
TOP_how_are= TOP_how_are.sort_values(by='mp_app_vote_percent', ascending=False)
#TOP_how_are

# %%
final_TOP5 = TOP_how_are.replace(to_replace=202.22338,
           value=math_pa(202.22338)).sort_values(by='mp_app_vote_percent', ascending=False)
#final_TOP5

# %% [markdown]
# #ในจังหวัดๆ นั้นมีว่าที่สส.คนไหนมีคะเเนนเสียงสูงสุด

# %%
bool_use = table_merge4.duplicated(subset='turn_out')
table_merge4 = table_merge4[~bool_use]
# displaying data
use_V1.info()
use_V1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 232
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   province      77 non-null     object
#  1   mp_app_vote_  77 non-null     int64
#  2   name          77 non-null     object
#  3   mp_app_name   77 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ KB
#           province  mp_app_vote_             name                mp_app_name
# 0           กระบี่         51845        ภูมิใจไทย    นายสฤษฏ์พงษ์ เกี่ยวข้อง
# 4    กรุงเทพมหานคร         50132          ก้าวไกล      นายศุภณัฐ มีนชัยนันท์
# 7        กาญจนบุรี         44813        ภูมิใจไทย      นายยศวัฒน์ มาไพศาลสิน
# 9        กาฬสินธุ์         56559         เพื่อไทย        นายวิรัช พิมพะนิตย์
# 12       กำแพงเพชร         41143     พลังประชารัฐ    นายเพชรภูมิ อาภรณ์รัตน์
# ..             ...           ...              ...                        ...
# 221       เพชรบุรี         40235  รวมไทยสร้างชาติ  นางธิวัลรัตน์ อังกินันทน์
# 223      เพชรบูรณ์         47118     พลังประชารัฐ            นายอัคร ทองใจสด
# 225            เลย         50421         เพื่อไทย        นายศรัณย์ ทิมสุวรรณ
# 230           แพร่         41565         เพื่อไทย          นายทศพร เสรีรักษ์
# 232     แม่ฮ่องสอน         20346     ประชาธิปัตย์         นายสมบัติ ยะสินธุ์
#
# [77 rows x 4 columns]

# %% [markdown]
# #สร้างตารางที่ประกอบด้วยชื่อภูมิภาค จำนวนผู้มาใช้สิทธิเเละจำนวนผู้มีสิทธิ์ในภาคนั้นๆ

# %% [markdown]
# ---

# %%
RR=table_merge4[['percent_turn_out','turn_out','province','region_name']]

# %%
KK=result_constituencies_status.merge(info_province, how='left',on='prov_id')
JJ = KK.merge(region, how='left',on='region_id')

# %% [markdown]
# ---

# %%
AA = JJ[['region_id','region_name']]

# %%
LL = JJ[['region_id','turn_out']]
DD=LL.groupby('region_id').sum().reset_index()

# %%
RR = info_province[['total_registered_vote','region_id']]
MM=RR.groupby('region_id').sum().reset_index()

# %%
MM['total_registered_vote'].sum()
# Out:
# 52238594

# %% [markdown]
# ---

# %%
BBB = DD.merge(MM, how='left',on='region_id')

# %%
AAA=BBB.merge(AA, how='left',on='region_id')
bool_use = AAA.duplicated(subset='region_id')
AAA = AAA[~bool_use]
# displaying data
AAA.info()
AAA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 371
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   region_id              6 non-null      object
#  1   turn_out               6 non-null      int64
#  2   total_registered_vote  6 non-null      int64
#  3   region_name            6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 240.0+ bytes
#     region_id  turn_out  total_registered_vote            region_name
# 0         R01   3878723                4912950               ภาคเหนือ
# 37        R02  12438019               17453038  ภาคตะวันออกเฉียงเหนือ
# 170       R03  12446904               16285167                ภาคกลาง
# 292       R04   5525020                7200448                 ภาคใต้
# 352       R05   2012921                2552747             ภาคตะวันตก
# 371       R06   2983165                3834244            ภาคตะวันออก

# %% [markdown]
# ## ลอง

# %%
#mpvp =find_proforconAB[find_proforconAB['mp_app_vote_percent'] > 100]

# %%
#mpvp

# %%
#list(mpvp['mp_app_vote_percent'])

# %%
#l = []
#for i in list(mpvp['mp_app_vote_percent']):
 # b = math_pa(i)
  #l.append(b)
#mpvp['mp_app_vote_percent'] = l

# %%
LL=table_merge4[['province','region_name','turn_out']]
bool_use = LL.duplicated(subset='province')
LL = LL[~bool_use]
LL
# Out:
#              province            region_name  turn_out
# 0          อำนาจเจริญ  ภาคตะวันออกเฉียงเหนือ    105574
# 25            อ่างทอง                ภาคกลาง     89756
# 42    พระนครศรีอยุธยา                ภาคกลาง    110317
# 94      กรุงเทพมหานคร                ภาคกลาง     94407
# 592            บึงกาฬ  ภาคตะวันออกเฉียงเหนือ     75682
# ...               ...                    ...       ...
# 4494         อุดรธานี  ภาคตะวันออกเฉียงเหนือ     90592
# 4655        อุทัยธานี                ภาคกลาง     92174
# 4671        อุตรดิตถ์               ภาคเหนือ     90413
# 4701             ยะลา                 ภาคใต้     99228
# 4744            ยโสธร  ภาคตะวันออกเฉียงเหนือ    110491
#
# [77 rows x 3 columns]

# %%
re_ture = LL.groupby('region_name').sum('turn_out')
re_ture.sum()
# Out:
# turn_out    7840532
# dtype: int64

# %% [markdown]
# #ส่วนที่อาจารย์ถามเพิ่ม (เมื่อเปรียบเทียบคนที่ได้เป็นสส.ว่าใครมีคะเเนนเสียงนับเป็นเปอร์เซ็นมากที่สุด)

# %%
P_C_PT = result_constituencies_Candidate.merge(info_party_overview, how ='left',left_on='party_id',right_on ='id')
P_C_PT1 = P_C_PT.merge(Candidate_Constituency, how ='left',on='mp_app_id')
P_C_PT2 = P_C_PT1[['cons_id','mp_app_name','name','mp_app_vote','mp_app_vote_percent']]
#PC_soft = P_C_PT[['cons_id','turn_out']].groupby('cons_id')

# %%
P_C_PT2[P_C_PT2['mp_app_vote_percent']> 100]
# Out:
#      cons_id                mp_app_name             name  mp_app_vote  \
# 2593   NST_6        นายถาวรวัฒน์ คงแก้ว         เพื่อไทย         5596
# 2594   NST_6         นายฉัตรชัย ธนาวุฒิ  รวมไทยสร้างชาติ         7731
# 2601   NST_6        นายประกอบ รัตนพันธ์     ประชาธิปัตย์         5574
# 2602   NST_6          นายสุธรรม จริตงาม     พลังประชารัฐ        27331
# 2605   NST_6  นายปิยวัฒน์ สิริพันธ์พงศ์          ก้าวไกล        10700
# 2606   NST_6    นายสมศักดิ์ แสงอารยะกุล        ภูมิใจไทย        23260
#
#       mp_app_vote_percent
# 2593            146.37719
# 2594            202.22338
# 2601            145.80173
# 2602            714.90976
# 2605            279.88491
# 2606            608.42270

# %%
def math_pa(x):
  y=(100*x)/1220778
  return y

# %%
P_C_PT3 = P_C_PT2.replace(to_replace=[146.37719,202.22338,145.80173,714.90976,279.88491,608.42270],
           value=[math_pa(146.37719),math_pa(202.22338),math_pa(145.80173),math_pa(714.90976),math_pa(279.88491),math_pa(608.42270)]).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
P_C_PT4=P_C_PT3[['cons_id','mp_app_vote']]

# %%
P_C_PT_sas = P_C_PT4.groupby('cons_id').max()

# %%
L = P_C_PT_sas.merge(P_C_PT3,how = 'left', on ='mp_app_vote')

# %%
L1 = L[['mp_app_vote','cons_id','mp_app_name','name','mp_app_vote_percent']]

# %%
bool_use = L1.duplicated(subset='mp_app_name')
P_C_PT_sasa = L1[~bool_use]
P_C_PT_sasa.drop([134,294,324,329],axis
= 0, inplace = True)
P_C_PT_sasa
# Out:
# <ipython-input-120-3b5796c32158>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P_C_PT_sasa.drop([134,294,324,329],axis
#      mp_app_vote cons_id              mp_app_name         name  \
# 0          38275   ACR_1   นางสุขสมรวย วันทนียกุล    ภูมิใจไทย
# 1          46881   ACR_2       นางญาณีนาถ เข็มนาค    ภูมิใจไทย
# 2          44725   ATG_1   นายภราดร ปริศนานันทกุล    ภูมิใจไทย
# 3          47232   ATG_2  นายกรวีร์ ปริศนานันทกุล    ภูมิใจไทย
# 4          41081   AYA_1     นายทวิวงศ์ โตทวิวงศ์      ก้าวไกล
# ..           ...     ...                      ...          ...
# 403        51946   YLA_2         นายซูการ์โน มะทา    ประชาชาติ
# 404        31741   YLA_3     นายอับดุลอายี สาแม็ง    ประชาชาติ
# 405        53130   YST_1        นางสุภาพร สลับศรี  ไทยสร้างไทย
# 406        44851   YST_2        นายบุญแก้ว สมวงศ์     เพื่อไทย
# 407        37946   YST_3        นายธนพัฒน์ ศรีชนะ    ภูมิใจไทย
#
#      mp_app_vote_percent
# 0               36.25419
# 1               41.92804
# 2               49.82954
# 3               51.63886
# 4               37.23905
# ..                   ...
# 403             51.78082
# 404             32.40332
# 405             48.08536
# 406             45.56547
# 407             36.30085
#
# [400 rows x 5 columns]

# %%
P_C_PT_sasa_percent = P_C_PT_sasa.reset_index().sort_values(by='mp_app_vote_percent', ascending=False)

# %%
sasa_has_Prov= P_C_PT_sasa_percent.merge(info_constituency,how ='left',on='cons_id')
bool5_use = sasa_has_Prov.duplicated(subset='mp_app_name')
sasa_has_Prov = sasa_has_Prov[~bool5_use]
# displaying data
sasa_has_Prov
bfuse_df_sasa = sasa_has_Prov[['cons_id','mp_app_name','name','mp_app_vote','mp_app_vote_percent','prov_id']]

# %%
bf1use_df_sasa=bfuse_df_sasa.merge(info_province,how ='left',on='prov_id')

# %%
use_df_sasa = bf1use_df_sasa[['cons_id','mp_app_name','name','mp_app_vote','mp_app_vote_percent','province']]

# %%
use_df_sasa
# Out:
#     cons_id                     mp_app_name             name  mp_app_vote  \
# 0     RET_5           นางสาวจิราพร สินธุไพร         เพื่อไทย        61288
# 1     CPM_2           นายเชิงชาย ชาลีรินทร์         เพื่อไทย        61414
# 2    UBN_10            นายสมศักดิ์ บุญประชม   เพื่อไทรวมพลัง        63127
# 3     TRG_2                  นายทวี สุระบาล     พลังประชารัฐ        63185
# 4     KSN_1             นายวิรัช พิมพะนิตย์         เพื่อไทย        56559
# ..      ...                             ...              ...          ...
# 395   PKN_3          นายประมวล พงศ์ถาวราเดช     ประชาธิปัตย์        20444
# 396   PTN_1  ผู้ช่วยศาสตราจารย์วรวิทย์ บารู        ประชาชาติ        13938
# 397   PBI_3     จ่าอากาศเอกอภิชาติ แก้วโกศล  รวมไทยสร้างชาติ        11597
# 398   PRI_3                  นายสุนทร คมคาย          ก้าวไกล         4218
# 399   NST_6               นายสุธรรม จริตงาม     พลังประชารัฐ        27331
#
#      mp_app_vote_percent         province
# 0              69.347580         ร้อยเอ็ด
# 1              63.438320          ชัยภูมิ
# 2              62.274460      อุบลราชธานี
# 3              60.291030             ตรัง
# 4              59.809650        กาฬสินธุ์
# ..                   ...              ...
# 395            19.757240  ประจวบคีรีขันธ์
# 396            18.523240          ปัตตานี
# 397            10.529140         เพชรบุรี
# 398             4.151490       ปราจีนบุรี
# 399             0.058562    นครศรีธรรมราช
#
# [400 rows x 6 columns]

# %% [markdown]
# #เช็กcolumns เเละเก็บข้อมูลเป็น csv

# %%
table_merge4.columns
# Out:
# Index(['cons_id', 'mp_app_id', 'mp_app_rank', 'mp_app_vote',
#        'mp_app_vote_percent', 'party_id', 'mp_app_name', 'mp_app_no',
#        'mp_app_party_id', 'image_url', 'id', 'party_no', 'name', 'abbr',
#        'color', 'logo_url', 'prov_id', 'turn_out', 'percent_turn_out',
#        'counted_vote_stations', 'percent_count', 'pause_report', 'province_id',
#        'province', 'eng', 'abbre_thai', 'total_registered_vote',
#        'total_vote_stations', 'region_id', 'region_name'],
#       dtype='object')

# %%
AAA.to_csv('NNN.csv', index=False)

# %%
final_TOP4.to_csv('ข้อมูลพลังประชารัฐ.csv', index=False)

# %%
final_TOP3.to_csv('ข้อมูลภูมิใจไทย.csv', index=False)

# %%
final_TOP2.to_csv('ข้อมูลเพื่อไทย.csv', index=False)

# %%
table_merge4.to_csv('table_merge_result_useforproject.csv', index=False)

# %%
use_V1.to_csv('use_V1.csv', index=False)

# %%
BBB.to_csv('นว2.csv', index=False)

# %%
use_df_sasa.to_csv('รายชื่อ สส.ในเเต่ละเขต.csv', index=False)

# %%
all1 = pd.concat([final_TOP1.head(5),final_TOP2.head(5),final_TOP3.head(5),final_TOP4.head(5),final_TOP5.head(5)])

# %%
L .to_csv('?L.csv', index=False)

# %%
#all1

# %%
final_TOP1.to_csv('ข้อมูลก้าวไกล.csv', index=False)
