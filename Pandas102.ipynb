# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/python_dataviz2023/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx')
sep_df
# Out:
#    เป้าหมายการเบิกจ่ายและการใช้จ่ายงบประมาณ พ.ศ. 2565          Unnamed: 1  \
# 0                                              รายการ         ไตรมาสที่ 1
# 1                                                 NaN            เบิกจ่าย
# 2                                              ภาพรวม                  30
# 3                                               ประจำ                  34
# 4                                               ลงทุน                  13
# 5   ผลการใช้จ่ายงบประมาณรายจ่ายจังหวัดเชียงใหม่ ปร...                 NaN
# 6                                                 NaN                 NaN
# 7                                              รายการ            งบประมาณ
# 8                     งบประมาณรายจ่ายประจำปี พ.ศ.2565                 NaN
# 9                                              ภาพรวม   28525389387.86998
# 10                                              ประจำ  18920131432.719986
# 11                                              ลงทุน   9605257955.149996
# ...

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx',header=8,skiprows=2)
sep_df
# Out:
#                                                ภาพรวม   28525389387.86998  \
# 0                                               ประจำ  18920131432.719986
# 1                                               ลงทุน   9605257955.149996
# 2   ค่าใช้จ่ายบรรเทาผลกระทบจากการแพร่ระบาดของ COVI...                 NaN
# 3                                              ภาพรวม       2997790719.61
# 4                                             เงินกู้       2461860887.43
# 5                                             ปี 2563         24020888.32
# 6                                             ปี 2564       1772476259.27
# 7                                             ปี 2565        665363739.84
# 8                                              งบกลาง        535929832.18
# 9                                             ปี 2564        384191433.43
# 10                                            ปี 2565        151738398.75
# 11                                                NaN                 NaN
# ...

# %%
sep_df.head() # ดูหัวตารางแถวบน
# Out:
#                                               ภาพรวม   28525389387.86998  \
# 0                                              ประจำ  18920131432.719986
# 1                                              ลงทุน   9605257955.149996
# 2  ค่าใช้จ่ายบรรเทาผลกระทบจากการแพร่ระบาดของ COVI...                 NaN
# 3                                             ภาพรวม       2997790719.61
# 4                                            เงินกู้       2461860887.43
#
#    347600454.93  1190636149.69   27003921829.55999 94.66626892407305    93  \
# 0   79257448.41    71316001.06  18801957159.449989         99.375405  98.0
# 1  268343006.52  1119320148.63       8201964670.11         85.390363  75.0
# 2           NaN            NaN                 NaN               NaN   NaN
# 3      55485.83    28344424.87       2786219946.98         92.942444   NaN
# 4             0    28344424.87       2256794827.16         91.670282   NaN
#
# ...

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx', header=8)
sep_df
# Out:
#                                                รายการ            งบประมาณ  \
# 0                     งบประมาณรายจ่ายประจำปี พ.ศ.2565                 NaN
# 1                                              ภาพรวม   28525389387.86998
# 2                                               ประจำ  18920131432.719986
# 3                                               ลงทุน   9605257955.149996
# 4   ค่าใช้จ่ายบรรเทาผลกระทบจากการแพร่ระบาดของ COVI...                 NaN
# 5                                              ภาพรวม       2997790719.61
# 6                                             เงินกู้       2461860887.43
# 7                                             ปี 2563         24020888.32
# 8                                             ปี 2564       1772476259.27
# 9                                             ปี 2565        665363739.84
# 10                                             งบกลาง        535929832.18
# 11                                            ปี 2564        384191433.43
# ...

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx', header=8, skiprows=2)
sep_df
# Out:
#                                                ภาพรวม   28525389387.86998  \
# 0                                               ประจำ  18920131432.719986
# 1                                               ลงทุน   9605257955.149996
# 2   ค่าใช้จ่ายบรรเทาผลกระทบจากการแพร่ระบาดของ COVI...                 NaN
# 3                                              ภาพรวม       2997790719.61
# 4                                             เงินกู้       2461860887.43
# 5                                             ปี 2563         24020888.32
# 6                                             ปี 2564       1772476259.27
# 7                                             ปี 2565        665363739.84
# 8                                              งบกลาง        535929832.18
# 9                                             ปี 2564        384191433.43
# 10                                            ปี 2565        151738398.75
# 11                                                NaN                 NaN
# ...

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx', header=8, skipfooter=26)
sep_df
# Out:
#                             รายการ      งบประมาณ  สำรองเงินมีหนี้  \
# 0  งบประมาณรายจ่ายประจำปี พ.ศ.2565           NaN              NaN
# 1                           ภาพรวม  2.852539e+10     3.476005e+08
# 2                            ประจำ  1.892013e+10     7.925745e+07
# 3                            ลงทุน  9.605258e+09     2.683430e+08
#
#              PO      เบิกจ่าย  ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  \
# 0           NaN           NaN               NaN            NaN           NaN
# 1  1.190636e+09  2.700392e+10         94.666269           93.0      1.666269
# 2  7.131600e+07  1.880196e+10         99.375405           98.0      1.375405
# 3  1.119320e+09  8.201965e+09         85.390363           75.0     10.390363
#
#    การใช้จ่าย (PO+เบิกจ่าย)  ร้อยละ\nการใช้จ่าย  ...  ลำดับ\nใช้จ่าย  \
# 0                       NaN                 NaN  ...             NaN
# 1              2.854216e+10          100.058786  ...            51.0
# ...

# %% [markdown]
# #Quiz 4
# ตัดตาราง sep_df ให้เหลือเฉพาะ  15 columns แรก และข้อมูลงบประจำกับงบทุน

# %%
drop15sep_df = sep_df.iloc[-2:,:15]
drop15sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย
# 2            -3.239918e+07            NaN             NaN
# 3             1.563013e+07            6.0            15.0

# %%
drop15sep_df['เดือน-ปี'] = len(drop15sep_df)*['sep-65']
drop15sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2            -3.239918e+07            NaN             NaN   sep-65
# 3             1.563013e+07            6.0            15.0   sep-65

# %%
oct_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/oct65.xlsx', header=9, skipfooter=27)
drop15oct_df = oct_df.iloc[-2:,:15]
drop15oct_df['เดือน-ปี'] = len(drop15oct_df)*['oct-65']
drop15oct_df
# Out:
#   รายการ     งบประมาณ  สำรองเงินมีหนี้          PO     เบิกจ่าย  \
# 2  ประจำ  6822.811789              NaN   12.706842  3984.779058
# 3  ลงทุน  6180.211723              NaN  457.295806  1291.209026
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q1  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         58.403766           35.0     23.403766               3997.485900
# 3         20.892634           19.0      1.892634               1748.504832
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q1.1  */- เป้าหมาย.1  \
# 2           58.590007            35.33       23.260007
# 3           28.291989            28.96       -0.668011
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2              2825.325889            NaN             NaN   oct-65
# 3              4431.706890            4.0             6.0   oct-65

# %% [markdown]
# # ต่อตาราง
#
#
# *   ต่อในเเนวเเกน Y (เพิ่มจำนวนข้อมูล)
# *   ต่อในเเนวเเกน X (เพิ่มรายละเอียดของข้อมูล)

# %% [markdown]
# ## ต่อตารางแกน Y (แกน rows)

# %%
sep_oct_df = pd.concat([sep_df, oct_df])
sep_oct_df
# Out:
#                             รายการ      งบประมาณ  สำรองเงินมีหนี้  \
# 0  งบประมาณรายจ่ายประจำปี พ.ศ.2565           NaN              NaN
# 1                           ภาพรวม  2.852539e+10     3.476005e+08
# 2                            ประจำ  1.892013e+10     7.925745e+07
# 3                            ลงทุน  9.605258e+09     2.683430e+08
# 0  งบประมาณรายจ่ายประจำปี พ.ศ.2565           NaN              NaN
# 1                           ภาพรวม  1.300302e+04              NaN
# 2                            ประจำ  6.822812e+03              NaN
# 3                            ลงทุน  6.180212e+03              NaN
#
#              PO      เบิกจ่าย  ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  \
# 0           NaN           NaN               NaN            NaN           NaN
# 1  1.190636e+09  2.700392e+10         94.666269           93.0      1.666269
# 2  7.131600e+07  1.880196e+10         99.375405           98.0      1.375405
# ...

# %% [markdown]
# # HW4
# จากตาราง ```sep_oct_df```
#
# 1.   งบประมาณประจำหรืองบประมาณลงทุน สูงกว่ากัน
# 2.   งบรวม เดือน oct หรือ sep อันไหนมากกว่ากัน
# 3.   แก้ค่า missing พร้อมทั้งให้เหตุผล
# 4.   เดือนไหนเบิกจ่ายรวมมากกว่ากัน (การใช้จ่าย (PO+เบิกจ่าย))

# %% [markdown]
# #ข้อ 1

# %%
import pandas as pd
import os

from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Dataviz2023'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx', header=8, skipfooter=26)
sep_df = sep_df.iloc[-2:,:15]
sep_df['เดือน-ปี'] = len(sep_df)*['sep-65']
sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2            -3.239918e+07            NaN             NaN   sep-65
# 3             1.563013e+07            6.0            15.0   sep-65

# %%
oct_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/oct65.xlsx', header=9, skipfooter=27)
oct_df = oct_df.iloc[-2:,:15]
oct_df['เดือน-ปี'] = len(oct_df)*['oct-65']
oct_df
# Out:
#   รายการ     งบประมาณ  สำรองเงินมีหนี้          PO     เบิกจ่าย  \
# 2  ประจำ  6822.811789              NaN   12.706842  3984.779058
# 3  ลงทุน  6180.211723              NaN  457.295806  1291.209026
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q1  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         58.403766           35.0     23.403766               3997.485900
# 3         20.892634           19.0      1.892634               1748.504832
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q1.1  */- เป้าหมาย.1  \
# 2           58.590007            35.33       23.260007
# 3           28.291989            28.96       -0.668011
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2              2825.325889            NaN             NaN   oct-65
# 3              4431.706890            4.0             6.0   oct-65

# %%
sep_oct_df = pd.concat([sep_df, oct_df])
sep_oct_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
# 2  ประจำ  6.822812e+03              NaN  1.270684e+01  3.984779e+03
# 3  ลงทุน  6.180212e+03              NaN  4.572958e+02  1.291209e+03
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
# 2         58.403766            NaN     23.403766              3.997486e+03
# 3         20.892634            NaN      1.892634              1.748505e+03
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
# 2           58.590007              NaN       23.260007
# ...

# %%
fix_sep = sep_oct_df[(sep_oct_df['รายการ']=='ประจำ')&( sep_oct_df['เดือน-ปี']=='sep-65')]['งบประมาณ']
invest_sep = sep_oct_df[(sep_oct_df['รายการ']=='ลงทุน')&( sep_oct_df['เดือน-ปี']=='sep-65')]['งบประมาณ']
fix_oct = sep_oct_df[(sep_oct_df['รายการ']=='ประจำ')&( sep_oct_df['เดือน-ปี']=='oct-65')]['งบประมาณ']
invest_oct = sep_oct_df[(sep_oct_df['รายการ']=='ลงทุน')&( sep_oct_df['เดือน-ปี']=='oct-65')]['งบประมาณ']
if int(fix_sep) > int(invest_sep): print(f'ในเดือนกันยายน งบประมาณประจำ สูงกว่างบประมาณลงทุนอยู่',int(fix_sep)-int(invest_sep),'บาท')
else: print (f'ในเดือนกันยายน งบประมาณลงทุน สูงกว่างบประมาณประจำอยู่',int(invest_sep)-int(fix_sep),'บาท')

if int(fix_oct) > int(invest_oct): print(f'ในเดือนตุลาคม งบประมาณประจำ สูงกว่างบประมาณลงทุนอยู่', int(fix_oct)-int(invest_oct),'บาท')
else: print (f'ในเดือนตุลาคม งบประมาณลงทุน สูงกว่างบประมาณประจำอยู่', int(invest_oct)-int(fix_oct),'บาท')
# Out:
# ในเดือนกันยายน งบประมาณประจำ สูงกว่างบประมาณลงทุนอยู่ 9314873477 บาท
# ในเดือนตุลาคม งบประมาณประจำ สูงกว่างบประมาณลงทุนอยู่ 642 บาท

# %% [markdown]
# #ข้่อ 2

# %%
total_sep = int(fix_sep) + int(invest_sep)
total_oct = int(fix_oct) + int(invest_oct)
if total_sep > total_oct : print(f'งบรวมเดือนกันยายนมากกว่าเดือนตุลาคมอยู่',(total_sep - total_oct), 'บาท')
else: print(f'งบรวมเดือนตุลาคมมากกว่าเดือนกันยายนอยู่',(total_oct - total_sep), 'บาท')
# Out:
# งบรวมเดือนกันยายนมากกว่าเดือนตุลาคมอยู่ 28525376385 บาท

# %% [markdown]
# #ข้อ 3

# %%
sep_oct_df = pd.concat([sep_df, oct_df])
sep_oct_df.rename(columns=lambda x: x.replace('\n', ''), inplace=True)
sep_oct_df.rename(columns=lambda x: x.replace('*/-', ''), inplace=True)
sep_oct_df.fillna('-', inplace = True)
sep_oct_df
# Out:
#   รายการ      งบประมาณ สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     79257448.41  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09    268343006.52  1.119320e+09  8.201965e+09
# 2  ประจำ  6.822812e+03               -  1.270684e+01  3.984779e+03
# 3  ลงทุน  6.180212e+03               -  4.572958e+02  1.291209e+03
#
#    ร้อยละเบิกจ่าย เป้าหมาย Q4   เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2       99.375405        98.0   1.375405              1.895253e+10
# 3       85.390363        75.0  10.390363              9.589628e+09
# 2       58.403766           -  23.403766              3.997486e+03
# 3       20.892634           -   1.892634              1.748505e+03
#
#    ร้อยละการใช้จ่าย เป้าหมาย Q4.1   เป้าหมาย.1  คงเหลือหลังหักใช้จ่าย  \
# 2        100.171242         100.0     0.171242          -3.239918e+07
# 3         99.837275         100.0    -0.162725           1.563013e+07
# 2         58.590007             -    23.260007           2.825326e+03
# ...

# %% [markdown]
# #ข้อ 4

# %%
PO_sep = sep_oct_df [( sep_oct_df['เดือน-ปี']=='sep-65')]['การใช้จ่าย (PO+เบิกจ่าย)'].sum()
PO_oct = sep_oct_df[( sep_oct_df['เดือน-ปี']=='oct-65')]['การใช้จ่าย (PO+เบิกจ่าย)'].sum()
if int(PO_sep) > int(PO_oct): print(f'เดือนกันยายน เบิกจ่ายรวมมากกว่า เดือนตุลาคมอยู่',int(PO_sep - PO_oct),'บาท')
else: print(f'เดือนตุลาคม เบิกจ่ายรวมมากกว่า เดือนกันยายนอยู่',int(PO_oct - PO_sep),'บาท')
# Out:
# เดือนกันยายน เบิกจ่ายรวมมากกว่า เดือนตุลาคมอยู่ 28542152688 บาท

# %% [markdown]
# #ต่อตารางแนวแกน x
# (เพิ่มรายละเอียดของข้อมูล)

# %%
project_df = pd.read_csv('/content/drive/MyDrive/DataViz23Data/Copy of opendata_project-2.csv')
project_df
# Out:
#        row_number                project_id                     name_en  \
# 0         20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1          4268.0             project_15905              Liberty Park 2
# 2          5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3         21762.0              project_6010              Baan Thara Rin
# 4         10751.0             project_11312             The Forest Hill
# ...           ...                       ...                         ...
# 23862     17534.0              project_9330   Parinyada Wongwan Sathorn
# 23863     12360.0              project_9316              Sinwong Garden
# 23864      6865.0             project_15993      La Maison Sukhumvit 22
# 23865        74.0               project_105                    Regent 1
# 23866     20538.0  5f2bcbd0306e7e0019068db0     Baanruenrom Nongphueng
#
#                           name_th propertytype_id propertytype_name_en  \
# ...

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/DataViz23Data/Copy of opendata_unittype-2.csv')
unit_df
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 2           12994            unittype_37624             project_16674
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# ...

# %%
project_df = project_df.drop_duplicates(subset='project_id')
unit_df['province_en'] = unit_df['project_id'].map(project_df.set_index('project_id')['province_name_en'])

# %%
unit_df[unit_df['propertytype_name_en']=='Condo'].sort_values(by=['price_min'])
# Out:
#        row_number               unittype_id                project_id  \
# 30708        5661            unittype_18085              project_7286
# 922         24813            unittype_18253              project_7374
# 1652         6043            unittype_19041              project_7623
# 23918       24495            unittype_15924              project_6214
# 3923         2932            unittype_15136              project_3945
# ...           ...                       ...                       ...
# 43310       21103  63b7919c722c810013293f0d  63b79163722c810013293f0b
# 43336       17210  6035fc6e4c81850012c1eac2  5e7d6f3b78c46b001ac658df
# 43340       23704            unittype_15979              project_5880
# 43353       19565  62872af93937f9001619948a  62872a8b3937f90016199482
# 43355       17263  60488b2e582962001402e663  60488aeca8b9ee0013d7ebac
#
#                   name_th  propertytype_id propertytype_name_en  \
# ...

# %%
unit_df[unit_df['propertytype_name_en']=='Condo'].sort_values(by=['price_min']).iloc[:3]
# Out:
#        row_number     unittype_id    project_id    name_th  propertytype_id  \
# 30708        5661  unittype_18085  project_7286  1 Bedroom                2
# 922         24813  unittype_18253  project_7374  1 Bedroom                2
# 1652         6043  unittype_19041  project_7623  1 Bedroom                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 30708                Condo                คอนโด                NaN
# 922                  Condo                คอนโด                NaN
# 1652                 Condo                คอนโด                NaN
#
#        area_usable_min  price_min  ...  count_room_living  count_room_maid  \
# 30708             33.0   100000.0  ...                NaN              NaN
# 922               24.0   100000.0  ...                NaN              NaN
# 1652              33.0   100000.0  ...                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# ...

# %%
unit_df[unit_df['propertytype_name_en']=='Condo'].sort_values(by=['price_min']).iloc[:3,-1]
# Out:
# 30708     Samut Prakan
# 922       Samut Prakan
# 1652     Nakhon Pathom
# Name: province_en, dtype: object

# %% [markdown]
# #Groupby

# %%
unit_df.groupby('province_en')['price_min'].min().head()
# Out:
# province_en
# Amnat Charoen    1000000.0
# Ang Thong        2590000.0
# Bangkok           130000.0
# Bung Kan         2890000.0
# Buri Ram          990000.0
# Name: price_min, dtype: float64

# %% [markdown]
# #*bonus* 10 อันดับอสังหาริมทรัพย์ที่แพงที่สุด 10 จังหวัดแรก

# %%
unit_df.groupby('province_en')['price_min'].max().head(10).sort_values()
# Out:
# province_en
# Ang Thong          3290000.0
# Chaiyaphum         3480000.0
# Bung Kan           3890000.0
# Amnat Charoen      4100000.0
# Buri Ram           7840000.0
# Chanthaburi        7900000.0
# Chiang Rai        11990000.0
# Chachoengsao      25800000.0
# Chiang Mai        54609600.0
# Bangkok          580000000.0
# Name: price_min, dtype: float64

# %%
unit_df.groupby('province_en')['price_min'].max().reset_index().sort_values(by='price_min',ascending=False).head(10)
# Out:
#             province_en    price_min
# 2               Bangkok  580000000.0
# 10            Chon Buri  385000000.0
# 33           Nonthaburi  185000000.0
# 45               Phuket  169000000.0
# 63          Surat Thani  124000000.0
# 47  Prachuap Khiri Khan   85000000.0
# 34         Pathum Thani   84000000.0
# 27    Nakhon Ratchasima   80000000.0
# 54         Samut Prakan   73000000.0
# 25        Nakhon Pathom   59000000.0

# %%
unit_df.groupby('province_en')['price_min'].max().reset_index().sort_values(by='price_min',ascending=False).head(10)

# %% [markdown]
# #create pandas table
